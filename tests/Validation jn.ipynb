# %% [markdown]
# # Comparaison entrer les projections de SimGen et de certaines données exsistantes

# %% [markdown]
# ## Effectuer une simulation avec Simgen

# %%
import sys
import warnings
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# Pour le moment, il faut changer les chemins pour les répertoires

# %%
sys.path.append('/Users/juliennavaux/Dropbox (CEDIA)/simgen/simgen/simgen')
import data

# %%
sys.path.append("/Users/juliennavaux/Dropbox (CEDIA)/simgen/simgen")
path_data = '/Users/juliennavaux/Dropbox (CEDIA)/simgem/Benchmark/'

# %%
from simgen import model

# %%
yr_debut=2017
yr_fin=2020

# %% [markdown]
# On simule la population jusqu'en {{yr_fin}}

# %%
base = model(start_yr=yr_debut,stop_yr=yr_fin)
base.startpop('/Users/juliennavaux/Dropbox (CEDIA)/simgen/simgen/tests/startpopiso')
base.immig_assumptions(init='newimmpopiso')
base.birth_assumptions(scenario='reference')
base.dead_assumptions(scenario='low')
base.risk_iso_assumtions(params_set=1)

# %%
base.simulate(rep=50)
# Out:
# year: 2020 replication: 50

# %%
#base.stats.save('simpop_iso.pkl')

# %% [markdown]
# # Extraction pour NJC et PCM

# %%
pd.read_pickle('Pour PC/simpop_iso.pkl').sum()
# Out:
# 2017         0.000000
# 2018    264801.750421
# 2019    274156.118777
# 2020    281755.015811
# 2021    287045.196226
# 2022    293307.884465
# 2023    302709.521749
# 2024    309258.538377
# 2025    319822.305388
# 2026    326795.373055
# 2027    334034.937560
# 2028    341392.520854
# 2029    350793.517318
# 2030    355006.539239
# 2031    362658.344301
# 2032    367469.047485
# 2033    369775.911757
# 2034    374658.263907
# 2035    375480.618620
# 2036    381270.006965
# 2037    385555.473406
# 2038    386951.666732
# 2039    386899.009722
# 2040    387964.900799
# 2041    390760.536355
# 2042    395238.943008
# 2043    396697.164864
# 2044    400007.116107
# 2045    403711.085965
# 2046    405683.195151
# 2047    406557.324298
# 2048    411612.308172
# 2049    409991.376219
# 2050    411427.008003
# 2051    417310.497400
# dtype: float64

# %%
#base.stats.freq('age', sub='age>=65 and age<=100 and risk_iso==True').loc[2018].to_excel("simpop_iso.xlsx")

# %%
#base.stats.freq('age', sub='age>=65 and age<=100 and risk_iso==True').to_excel("Pour PC/simpop_iso.xlsx")

# %%
#base.stats.freq('age', sub='age>=65 and age<=100 and risk_iso==True').to_pickle("Pour PC/simpop_iso.xlsx")

# %%
#pd.read_pickle('Pour PC/simpop_iso.pkl')
# Out:
#      2017          2018          2019          2020          2021  \
# age
# 65    0.0  15826.030085  15907.535963  16829.134291  16724.160118
# 66    0.0  14220.171143  15842.240650  15661.895461  16663.674083
# 67    0.0  13357.173275  14643.232002  15640.558821  15775.059804
# 68    0.0  14225.849871  13871.516784  14634.598326  14665.240138
# 69    0.0  13787.308268  14761.638082  13656.341634  14686.819921
# 70    0.0  13343.409491  13007.022192  14180.211486  13600.526866
# 71    0.0  15079.391495  15433.179158  15234.304784  15744.833877
# 72    0.0  11709.844546  13017.940402  12927.981839  12667.026915
# 2027   426.415850   397.253859   97.227421  154.133389   22.136060
# 2028   543.708692   688.415779  201.972546  169.397321   57.676247
# 2029   526.377866   531.871496  256.441035  187.290084   90.750445
# 2030   526.034344   474.533584  192.400572  216.113175   73.547777
# 2031   472.174923   669.360028  256.337126  128.107317   53.634141
# 2032   508.686547   482.439783  282.857176  178.213816   64.431035
# 2033   435.175624   527.818706  216.254979  202.223353   49.348404
# 2034   572.740405   482.574009  227.765534  142.751169  119.579032
# 2035   585.738339   573.020853  209.361306  211.732003   32.534924
# 2036   679.096123   572.460940  279.947456  209.432300   63.913465
# 2037   684.398397   681.480570  296.986185  246.608095   80.094770
# 2038   858.980184   798.845957  289.778481  253.908228   52.985976
# 2039   777.307296   736.925261  280.298614  188.152435   78.867803
# 2040   753.961416   572.438764  313.659932  234.502672   82.108682
# 2041   977.423907   836.316798  345.975795  231.815329   35.824936
# 2042   990.609056   807.170436  441.052887  272.951778  132.168613
# 2043  1031.869138  1132.099917  255.939350  336.317081   51.900450
# 2044  1207.905247  1187.259811  361.552168  276.286130   90.377043
# 2045   992.243330  1142.521085  490.114409  378.030662   53.322610
# 2046  1063.350703  1016.754716  377.860542  303.101135  136.762716
# 2047  1175.823803  1232.740237  330.489124  497.677546  105.478522
# 2048  1288.352254  1202.551086  466.672951  368.811553  129.884359
# 2049  1145.851406  1453.657475  412.384674  393.118889  109.619933
# 2050  1314.582257  1354.647359  462.458668  532.425703  242.739428
# 2051  1429.527309  1473.774287  598.720374  483.860660  169.811223
#
# [35 rows x 36 columns]

# %%
base.stats.freq(sub='age>=65 and age<=69')
# Out:
# 2017    490967.548132
# 2018    499773.362535
# 2019    512097.910846
# 2020    527177.143212
# 2021    539998.746262
# dtype: float64

# %%
base.stats.freq( sub='age>=70 and age<=74')
# Out:
# 2017    390921.164679
# 2018    409153.678583
# 2019    423986.456312
# 2020    437410.835024
# 2021    450523.783359
# dtype: float64

# %%
base.stats.freq( sub='age>=75 and age<=79')
# Out:
# 2017    266081.764852
# 2018    280516.389233
# 2019    295839.181446
# 2020    311123.259033
# 2021    327687.694861
# dtype: float64

# %%
base.stats.freq( sub='age>=80')
# Out:
# 2017    377351.229757
# 2018    378231.787858
# 2019    380049.456126
# 2020    384556.211939
# 2021    394086.369954
# dtype: float64

# %% [markdown]
# ## Extraction des résultats
# Creation de "DataFrame" contenant la population totale par sexe

# %% [raw]
# Analyse des risques iso

# %%
base.stats.freq('risk_iso')[True]
# Out:
# 2017         0.000000
# 2018    265139.972546
# 2019    273886.586246
# 2020    279943.056997
# 2021    291237.162635
# Name: True, dtype: float64

# %%
plt.figure()
plt.plot(base.stats.freq('risk_iso', sub='age>=65')[True],label="Nombre de personnes en risk_iso à 65 ans et plus")
plt.plot(base.stats.freq('risk_iso', sub='age>=75')[True],label="Nombre de personnes en risk_iso à 75 ans et plus")
plt.plot(base.stats.freq('risk_iso', sub='age>=85')[True],label="Nombre de personnes en risk_iso à 85 ans et plus")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(base.stats.freq('risk_iso', sub='age>=65')[True]/(base.stats.freq('risk_iso', sub='age>=65')[True]+base.stats.freq('risk_iso', sub='age>=65')[False])*100,label="Proportion de personnes en risk_iso à 65 ans et + (en %)")
plt.plot(base.stats.freq('risk_iso', sub='age>=75')[True]/(base.stats.freq('risk_iso', sub='age>=75')[True]+base.stats.freq('risk_iso', sub='age>=75')[False])*100,label="Proportion de personnes en risk_iso à 75 ans et + (en %)")
plt.plot(base.stats.freq('risk_iso', sub='age>=85')[True]/(base.stats.freq('risk_iso', sub='age>=85')[True]+base.stats.freq('risk_iso', sub='age>=85')[False])*100,label="Proportion de personnes en risk_iso à 85 ans et + (en %)")
plt.legend()
plt.show()

# %%
base.stats.freq('risk_iso', sub='age>=65')[True][2018]/(base.stats.freq('risk_iso', sub='age>=65')[True][2018]+base.stats.freq('risk_iso', sub='age>=65')[False][2018])
# Out:
# 0.169485499860269

# %%
base.stats.freq('risk_iso', sub='age>=75')[True][2018]/(base.stats.freq('risk_iso', sub='age>=75')[True][2018]+base.stats.freq('risk_iso', sub='age>=75')[False][2018])
# Out:
# 0.19749006739502084

# %%
base.stats.freq('risk_iso', sub='age>=80')[True][2018]/(base.stats.freq('risk_iso', sub='age>=80')[True][2018]+base.stats.freq('risk_iso', sub='age>=80')[False][2018])
# Out:
# 0.20434429184836092

# %% [raw]
# Profils par âge

# %%
profiles = pd.DataFrame(columns=['risk','no_risk'])

# %%
for i in range(65, 98):
    profiles.loc[i,'risk'] =  base.stats.freq('risk_iso', sub='age=='+str(i))[True][2018]
    profiles.loc[i,'no_risk'] =  base.stats.freq('risk_iso', sub='age=='+str(i))[False][2018]

# %%
plt.figure()
plt.plot(profiles.loc[:,'risk'],label="N risk_iso en 2018", color="green")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(profiles.loc[:,'risk']/(profiles.loc[:,'risk']+profiles.loc[:,'no_risk']),label="% risk_iso en 2018", color="green")
plt.legend()
plt.ylim(0,0.3)
plt.show()

# %% [markdown]
# Validations par classes d'âge

# %%
base.stats.prop('risk_iso', sub='age>=65 and age<=74')[True][2020]
# Out:
# 0.14584216470931555

# %%
base.stats.prop('risk_iso', sub='age>=75')[True][2020]
# Out:
# 0.19659875485556677

# %%
base.stats.prop('risk_iso', sub='age>=65 and age<=74 and male==True')[True][2020]
# Out:
# 0.1489697577749549

# %%
base.stats.prop('risk_iso', sub='age>=75 and male==True')[True][2020]
# Out:
# 0.20620915252654648

# %%
base.stats.prop('risk_iso', sub='age>=65 and age<=74 and male==False')[True][2020]
# Out:
# 0.14286041737835348

# %%
base.stats.prop('risk_iso', sub='age>=75 and male==False')[True][2020]
# Out:
# 0.18949595932043137

# %%
profiles = pd.DataFrame()

# %%
profiles.loc['6569','h_risk'] =  base.stats.freq('risk_iso', sub='age>=65 and age<=69 and male==1')[True][2020]
profiles.loc['6569','h_no_risk'] =  base.stats.freq('risk_iso', sub='age>=65 and age<=69 and male==1')[False][2020]
profiles.loc['7074','h_risk'] =  base.stats.freq('risk_iso', sub='age>=70 and age<=74 and male==1')[True][2020]
profiles.loc['7074','h_no_risk'] =  base.stats.freq('risk_iso', sub='age>=70 and age<=74 and male==1')[False][2020]
profiles.loc['7579','h_risk'] =  base.stats.freq('risk_iso', sub='age>=75 and age<=79 and male==1')[True][2020]
profiles.loc['7579','h_no_risk'] =  base.stats.freq('risk_iso', sub='age>=75 and age<=79 and male==1')[False][2020]
profiles.loc['80p','h_risk'] =  base.stats.freq('risk_iso', sub='age>=80  and male==1')[True][2020]
profiles.loc['80p','h_no_risk'] =  base.stats.freq('risk_iso', sub='age>=80  and male==1')[False][2020]

profiles.loc['6569','f_risk'] =  base.stats.freq('risk_iso', sub='age>=65 and age<=69 and male==0')[True][2020]
profiles.loc['6569','f_no_risk'] =  base.stats.freq('risk_iso', sub='age>=65 and age<=69 and male==0')[False][2020]
profiles.loc['7074','f_risk'] =  base.stats.freq('risk_iso', sub='age>=70 and age<=74 and male==0')[True][2020]
profiles.loc['7074','f_no_risk'] =  base.stats.freq('risk_iso', sub='age>=70 and age<=74 and male==0')[False][2020]
profiles.loc['7579','f_risk'] =  base.stats.freq('risk_iso', sub='age>=75 and age<=79 and male==0')[True][2020]
profiles.loc['7579','f_no_risk'] =  base.stats.freq('risk_iso', sub='age>=75 and age<=79 and male==0')[False][2020]
profiles.loc['80p','f_risk'] =  base.stats.freq('risk_iso', sub='age>=80  and male==0')[True][2020]
profiles.loc['80p','f_no_risk'] =  base.stats.freq('risk_iso', sub='age>=80  and male==0')[False][2020]

# %%
profiles
# Out:
#             h_risk      h_no_risk        f_risk      f_no_risk
# 6569  36838.620106  222816.826761  38300.602494  228994.523176
# 7074  35607.030806  175263.936789  32600.448535  193529.040311
# 7579  27274.516738  120138.127186  30450.010082  135575.867930
# 80p   35186.733385  116212.073462  44104.837359  191351.367829

# %%
profiles['hommes'] = profiles['h_risk'] / (profiles['h_risk']+profiles['h_no_risk'])
profiles['femmes'] = profiles['f_risk'] / (profiles['f_risk']+profiles['f_no_risk'])

# %%
profiles
# Out:
#             h_risk      h_no_risk        f_risk      f_no_risk    hommes  \
# 6569  36838.620106  222816.826761  38300.602494  228994.523176  0.141875
# 7074  35607.030806  175263.936789  32600.448535  193529.040311  0.168857
# 7579  27274.516738  120138.127186  30450.010082  135575.867930  0.185022
# 80p   35186.733385  116212.073462  44104.837359  191351.367829  0.232411
#
#         femmes
# 6569  0.143290
# 7074  0.144167
# 7579  0.183405
# 80p   0.187317

# %%
profiles.loc['6569','hommes_NJ'] = 0.1340
profiles.loc['6569','femmes_NJ'] = 0.1371

profiles.loc['7074','hommes_NJ'] = 0.1832
profiles.loc['7074','femmes_NJ'] = 0.1292

profiles.loc['7579','hommes_NJ'] = 0.2047
profiles.loc['7579','femmes_NJ'] = 0.2163

profiles.loc['80p','hommes_NJ'] = 0.2764
profiles.loc['80p','femmes_NJ'] = 0.2290

# %%
plt.figure()
plt.plot(profiles.loc[:,'hommes'],label="hommes simgen", color="blue")
plt.plot(profiles.loc[:,'femmes'],label="femmes simgen", color="red")
plt.plot(profiles.loc[:,'hommes_NJ'],label="hommes graphique NJ", color="blue", linestyle='dashed')
plt.plot(profiles.loc[:,'femmes_NJ'],label="femmes graphique NJ", color="red", linestyle='dashed')
plt.legend()
plt.ylim(0, 0.4)
plt.show()

# %% [raw]
# Bases pour Nicholas-James

# %%
iso = base.stats.freq('iso_smaf', sub='age>=65 and risk_iso==True')
iso.to_excel("Pour NJ/proportions.xlsx")

# %%
risk = base.stats.prop('risk_iso', sub='age>=65')
risk.loc[:,True].to_excel("Pour NJ/iso1_65p.xlsx") 
risk = base.stats.prop('risk_iso', sub='age>=65 and age<=74')
risk.loc[:,True].to_excel("Pour NJ/iso1_6574.xlsx") 
risk = base.stats.prop('risk_iso', sub='age>=75 and age<=84')
risk.loc[:,True].to_excel("Pour NJ/iso1_7584.xlsx") 
risk = base.stats.prop('risk_iso', sub='age>=85')
risk.loc[:,True].to_excel("Pour NJ/iso1_85p.xlsx")

# %% [markdown]
# Analyse des iso_smaf

# %%
base.stats.prop('iso_smaf', sub='age>=65 and risk_iso==True').loc[2020]
# Out:
# iso_smaf
# 1     0.576505
# 2     0.110075
# 3     0.069656
# 4     0.061096
# 5     0.034140
# 6     0.052511
# 7     0.013102
# 8     0.014548
# 9     0.011344
# 10    0.001684
# 11    0.055339
# Name: 2020, dtype: float64

# %%
base.stats.prop('iso_smaf', sub='age>=75 and risk_iso==True').loc[2020]
# Out:
# iso_smaf
# 1     0.377444
# 2     0.133752
# 3     0.095380
# 4     0.087590
# 5     0.054729
# 6     0.084617
# 7     0.022730
# 8     0.024067
# 9     0.018890
# 10    0.003043
# 11    0.097757
# Name: 2020, dtype: float64

# %%
base.stats.prop('risk_iso', sub='age>=65').loc[2020]
# Out:
# risk_iso
# False    0.832845
# True     0.167155
# Name: 2020, dtype: float64

# %%
base.stats.freq('risk_iso', sub='age>=80').loc[2020]
# Out:
# risk_iso
# False    307023.987583
# True      79608.458934
# Name: 2020, dtype: float64

# %%
base.stats.freq('iso_smaf').loc[2020]/1000
# Out:
# iso_smaf
# -1     7905.228634
#  1      160.258894
#  2       30.599103
#  3       19.363119
#  4       16.983756
#  5        9.490233
#  6       14.597194
#  7        3.642064
#  8        4.044167
#  9        3.153533
#  10       0.468077
#  11      15.383353
# Name: 2020, dtype: float64

# %%
base.stats.prop('iso_smaf', sub='age>=75 and risk_iso==True').loc[2020]
# Out:
# iso_smaf
# 1     0.377444
# 2     0.133752
# 3     0.095380
# 4     0.087590
# 5     0.054729
# 6     0.084617
# 7     0.022730
# 8     0.024067
# 9     0.018890
# 10    0.003043
# 11    0.097757
# Name: 2020, dtype: float64

# %%
base.stats.prop('iso_smaf', sub='age>=85 and risk_iso==True').loc[2020]
# Out:
# iso_smaf
# 1     0.155336
# 2     0.119281
# 3     0.096194
# 4     0.100773
# 5     0.077597
# 6     0.125385
# 7     0.038221
# 8     0.041992
# 9     0.031071
# 10    0.006987
# 11    0.207163
# Name: 2020, dtype: float64

# %%
proportions = pd.DataFrame(columns=['simgen','observé'])

# %%
proportions.loc[1,'observé'] = 0.334
proportions.loc[2,'observé'] = 0.132
proportions.loc[3,'observé'] = 0.096
proportions.loc[4,'observé'] = 0.098
proportions.loc[5,'observé'] = 0.061
proportions.loc[6,'observé'] = 0.092
proportions.loc[7,'observé'] = 0.024
proportions.loc[8,'observé'] = 0.029
proportions.loc[9,'observé'] = 0.025
proportions.loc[10,'observé'] = 0.003
proportions.loc[11,'observé'] = 0.107

# %%
for i in range(1, 12):
    proportions.loc[i,'simgen'] =  base.stats.prop('iso_smaf', sub='age>=75 and risk_iso==True').loc[2018,i]

# %%
proportions['diff'] = (proportions['simgen']-proportions['observé'])*100
proportions
# Out:
#         simgen observé      diff
# 1      0.38165   0.334   4.76501
# 2     0.127806   0.132 -0.419351
# 3    0.0893566   0.096 -0.664337
# 4    0.0969428   0.098 -0.105722
# 5    0.0517315   0.061  -0.92685
# 6    0.0824587   0.092 -0.954126
# 7    0.0207396   0.024 -0.326041
# 8    0.0274557   0.029 -0.154427
# 9    0.0234803   0.025 -0.151968
# 10  0.00469018   0.003  0.169018
# 11    0.093688   0.107   -1.3312

# %%
proportions.to_excel("Pour NJ/proportions des iso.xlsx")

# %%
base.stats.freq('risk_iso', sub='age>=65 and risk_iso==True')
# Out:
# risk_iso           True
# 2017           0.000000
# 2018      265139.972546
# 2019      273886.586246
# 2020      279943.056997
# 2021      291237.162635

# %%
base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0')
# Out:
# iso_smaf             1             2             3             4   \
# 2017           0.000000      0.000000      0.000000      0.000000
# 2018      155558.286844  27902.625724  16837.888881  17221.414614
# 2019      160235.629747  27737.485540  18018.839825  16080.382288
# 2020      158806.957533  31332.896806  19831.987529  18498.913359
# 2021      164380.291293  33977.730924  21172.501603  19117.450604
#
# iso_smaf            5             6            7            8            9   \
# 2017          0.000000      0.000000     0.000000     0.000000     0.000000
# 2018       9165.797720  13314.511271  3120.057331  4196.606779  3701.643587
# 2019      10914.177882  14934.885492  3103.241468  4403.073310  3611.725603
# 2020       9985.082386  14949.171074  3023.933152  3726.123207  3325.509869
# 2021      11269.723049  14149.536287  2791.416992  4388.896034  4005.356149
#
# iso_smaf          10            11
# 2017        0.000000      0.000000
# 2018      620.073186  13501.066610
# 2019      191.279992  14655.865099
# 2020      681.721871  15780.760212
# 2021      768.727116  15215.532583

# %%
base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0').plot.area()

# %%
base.stats.prop('iso_smaf', sub='age>=75 and age<=84 and iso_smaf>0').T[2020]
# Out:
# iso_smaf
# 1     0.468900
# 2     0.148893
# 3     0.090386
# 4     0.087411
# 5     0.041241
# 6     0.066517
# 7     0.015012
# 8     0.014985
# 9     0.013956
# 10    0.001182
# 11    0.051515
# Name: 2020, dtype: float64

# %%
base.stats.prop('iso_smaf', sub='age>=75 and risk_iso==True').T[2020]
# Out:
# iso_smaf
# 1     0.372689
# 2     0.131883
# 3     0.094295
# 4     0.100151
# 5     0.054936
# 6     0.088218
# 7     0.017730
# 8     0.021521
# 9     0.019623
# 10    0.004301
# 11    0.094653
# Name: 2020, dtype: float64

# %%
x=base.stats.freq('iso_smaf', sub='age>=65 and age<=74 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/freq_65-74.xlsx')
x=base.stats.prop('iso_smaf', sub='age>=65 and age<=74 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/Prop_65-74.xlsx')

x=base.stats.freq('iso_smaf', sub='age>=75 and age<=84 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/freq_75-84.xlsx')
x=base.stats.prop('iso_smaf', sub='age>=75 and age<=84 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/Prop_75-84.xlsx')

x=base.stats.freq('iso_smaf', sub='age>=85 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/freq_85p.xlsx')
x=base.stats.prop('iso_smaf', sub='age>=85 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/Prop_85p.xlsx')

# %%
x=base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/freq_65p.xlsx')
x=base.stats.prop('iso_smaf', sub='age>=65 and iso_smaf>0').T[2020]
x.to_excel('Pour NJ/Prop_65p.xlsx')

# %%
base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0')
# Out:
# iso_smaf             1             2             3             4   \
# 2017           0.000000      0.000000      0.000000      0.000000
# 2018      155558.286844  27902.625724  16837.888881  17221.414614
# 2019      160235.629747  27737.485540  18018.839825  16080.382288
# 2020      158806.957533  31332.896806  19831.987529  18498.913359
# 2021      164380.291293  33977.730924  21172.501603  19117.450604
#
# iso_smaf            5             6            7            8            9   \
# 2017          0.000000      0.000000     0.000000     0.000000     0.000000
# 2018       9165.797720  13314.511271  3120.057331  4196.606779  3701.643587
# 2019      10914.177882  14934.885492  3103.241468  4403.073310  3611.725603
# 2020       9985.082386  14949.171074  3023.933152  3726.123207  3325.509869
# 2021      11269.723049  14149.536287  2791.416992  4388.896034  4005.356149
#
# iso_smaf          10            11
# 2017        0.000000      0.000000
# 2018      620.073186  13501.066610
# 2019      191.279992  14655.865099
# 2020      681.721871  15780.760212
# 2021      768.727116  15215.532583

# %%
base.stats.freq('iso_smaf', sub='age>=65 and age<=74 and iso_smaf>0').plot.area()

# %%
base.stats.freq(sub='age>=65 and age<=74').plot()

# %%
base.stats.freq('iso_smaf', sub='age>=75 and iso_smaf>0').plot.area()

# %%
base.stats.freq('iso_smaf', sub='age>=85 and iso_smaf>0').plot.area()

# %%
prop_2020_65=(base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0').T[2020]
              /base.stats.freq('iso_smaf', sub='age>=65 and iso_smaf>0').T[2020].sum())
prop_2020_65.plot.bar()

# %%
prop_2020_75=(base.stats.freq('iso_smaf', sub='age>=75 and iso_smaf>0').T[2020]
              /base.stats.freq('iso_smaf', sub='age>=75 and iso_smaf>0').T[2020].sum())
prop_2020_75.plot.bar()

# %%
prop_2020_85=(base.stats.freq('iso_smaf', sub='age>=85 and iso_smaf>0').T[2020]
              /base.stats.freq('iso_smaf', sub='age>=85 and iso_smaf>0').T[2020].sum())
prop_2020_85.plot.bar()

# %%
base.stats.prop('risk_iso', sub='age>=65 and age<70').plot()

# %%
base.stats.prop('risk_iso', sub='age>=70 and age<75').plot()

# %%
base.stats.prop('risk_iso', sub='age>=85').plot()

# %%
base.stats.prop('risk_iso', sub='age>=95').plot()

# %% [markdown]
# Benchmark pour les profils par âge
# https://www.stat.gouv.qc.ca/statistiques/sante/bulletins/zoom-sante-201605.pdf

# %%
base.stats.prop('risk_iso', sub='age>=65').T[2020]
# Out:
# risk_iso
# False    0.831493
# True     0.168507
# Name: 2020, dtype: float64

# %%
base.stats.prop('risk_iso', sub='age>=65 and age<=74').T[2018]
# Out:
# risk_iso
# False    0.850789
# True     0.149211
# Name: 2018, dtype: float64

# %%
base.stats.prop('risk_iso', sub='age>=75').T[2018]
# Out:
# risk_iso
# False    0.80251
# True     0.19749
# Name: 2018, dtype: float64

# %% [markdown]
# hommes

# %%
base.stats.prop('risk_iso', sub='male==True and age>=65 and age<=74').T[2018]
# Out:
# risk_iso
# False    0.844827
# True     0.155173
# Name: 2018, dtype: float64

# %%
base.stats.prop('risk_iso', sub='male==True and age>=75').T[2018]
# Out:
# risk_iso
# False    0.787187
# True     0.212813
# Name: 2018, dtype: float64

# %% [markdown]
# femmes

# %%
base.stats.prop('risk_iso', sub='male==False and age>=65 and age<=74').T[2018]
# Out:
# risk_iso
# False    0.856485
# True     0.143515
# Name: 2018, dtype: float64

# %%
base.stats.prop('risk_iso', sub='male==False and age>=75').T[2018]
# Out:
# risk_iso
# False    0.813541
# True     0.186459
# Name: 2018, dtype: float64

# %% [markdown]
# Niveau d'études selon le groupe d'âge

# %%
base.stats.prop('educ', sub='age>=65 and age<=69').T[2018]
# Out:
# educ
# dec     0.269871
# des     0.198219
# none    0.358277
# uni     0.173633
# Name: 2018, dtype: float64

# %%
base.stats.prop('educ', sub='age>=70 and age<=74').T[2018]
# Out:
# educ
# dec     0.181861
# des     0.175712
# none    0.486019
# uni     0.156408
# Name: 2018, dtype: float64

# %%
base.stats.prop('educ', sub='age>=75 and age<=79').T[2018]
# Out:
# educ
# dec     0.176677
# des     0.198020
# none    0.534104
# uni     0.091199
# Name: 2018, dtype: float64

# %%
base.stats.prop('educ', sub='age>=80').T[2018]
# Out:
# educ
# dec     0.140007
# des     0.197879
# none    0.617092
# uni     0.045022
# Name: 2018, dtype: float64

# %%
base.stats.prop('educ', sub='age>=65').T[2018]
# Out:
# educ
# dec     0.198961
# des     0.192238
# none    0.485414
# uni     0.123387
# Name: 2018, dtype: float64

# %% [markdown]
# # Nombre de personnes en 11+ avec le fichier que nous a envoyé Hébert

# %% [markdown]
# SAD	190000 * 0.041
# CHSLD	55063 * 0.6688
# RI	17851 * 0.076

# %%
190000 * 0.041 + 55063 * 0.6688 + 17851 * 0.076
# Out:
# 45972.810399999995

# %% [markdown]
# # Comparaison des ISO-SMAF avec Hébert (2009-2010)

# %%
hebert = pd.DataFrame()

# %%
hebert['simgen'] = base.stats.freq('iso_smaf', sub='age>=75 and age<=84 and iso_smaf>0').T[2020]

# %%
hebert.loc[1,'hébert']=60559
hebert.loc[2,'hébert']=34261
hebert.loc[3,'hébert']=27675
hebert.loc[4,'hébert']=42627
hebert.loc[5,'hébert']=23214
hebert.loc[6,'hébert']=37719
hebert.loc[7,'hébert']=9833
hebert.loc[8,'hébert']=16433
hebert.loc[9,'hébert']=18125
hebert.loc[10,'hébert']=9683
c.loc[11,'hébert']=8055+7780+9699+7786
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-205f42b6a587> in <module>
#       9 hebert.loc[9,'hébert']=18125
#      10 hebert.loc[10,'hébert']=9683
# ---> 11 c.loc[11,'hébert']=8055+7780+9699+7786
#
# NameError: name 'c' is not defined

# %%
hebert
# Out:
#                 simgen   hébert
# iso_smaf
# 1         45522.651211  60559.0
# 2         14455.153169  34261.0
# 3          8775.041478  27675.0
# 4          8486.162527  42627.0
# 5          4003.869152  23214.0
# 6          6457.753366  37719.0
# 7          1457.465918   9833.0
# 8          1454.805582  16433.0
# 9          1354.920964  18125.0
# 10          114.765088   9683.0
# 11         5001.273203      NaN

# %%
hebert_norm = hebert
hebert_norm.loc[1,:]=0
hebert_norm.loc[:,'simgen'] = hebert_norm.loc[:,'simgen']/hebert_norm.loc[:,'simgen'].sum()
hebert_norm.loc[:,'hébert'] = hebert_norm.loc[:,'hébert']/hebert_norm.loc[:,'hébert'].sum()

# %%
hebert_norm
# Out:
#             simgen    hébert
# iso_smaf
# 1         0.000000  0.000000
# 2         0.280349  0.156037
# 3         0.170187  0.126042
# 4         0.164584  0.194139
# 5         0.077653  0.105725
# 6         0.125244  0.171786
# 7         0.028267  0.044783
# 8         0.028215  0.074842
# 9         0.026278  0.082548
# 10        0.002226  0.044100
# 11        0.096997       NaN

# %%
hebert.plot()

# %%
hebert_norm.plot()

# %%
lieu = pd.DataFrame()

# %%
lieu.loc['CHSLD','simgen']=55063
lieu.loc['SAD','simgen']=190000
lieu.loc['RI','simgen']=17851
lieu.loc['RPAS','simgen']=0
lieu.loc['Domicile sans services','simgen']=0

lieu.loc['CHSLD','hébert']=34350
lieu.loc['SAD','hébert']=158495
lieu.loc['RI','hébert']=7619
lieu.loc['CHSLD','hébert']=34350
lieu.loc['RPAS','hébert']=98223
lieu.loc['Domicile sans services','hébert']=14717

# %%
lieu
# Out:
#                           simgen    hébert
# CHSLD                    55063.0   34350.0
# SAD                     190000.0  158495.0
# RI                       17851.0    7619.0
# RPAS                         0.0   98223.0
# Domicile sans services       0.0   14717.0

# %%
pop =base.stats.freq()
pop_m=base.stats.freq(sub='male==True')
pop_f=base.stats.freq(sub='male==False')

# %% [markdown]
# Creation de "DataFrame" contenant la populaton par groupe d'âge

# %%
pop_age=base.stats.freq('age')
bins=[-1,4,9,14,19,24,29,34,39,44,49,54,59,64,69,74,79,84,89,101]
bins_3=[-1,24,64,101]
pop_age_gr=base.stats.freq('age', bins=bins)
pop_age_gr.columns= pop_age_gr.columns.astype('str')
pop_age_gr3=base.stats.freq('age', bins=bins_3)
base.stats.freq('age', sub="age>=6 and age<=10").plot()

# %%
base.stats.freq('age', sub="age>=11 and age<=16").plot()

# %% [markdown]
# On charge ici les données provenant des derninères projections de l'ISQ.
#
# Il s'agit de projections de population basées sur le scénario moyen de l'ISQ à partir des données corrigées du recensement de 2016. Pour plus d'information concernant la méthodologie utilisée pour le calcul des projections de population, veuillez-vous référer au rapport « Perspectives démographiques du Québec et des régions, 2016-2066, édition 2019 » produit par l'ISQ à l'adresse suivante :
#
# https://www.stat.gouv.qc.ca/statistiques/population-demographie/perspectives/perspectives-2016-2066.pdf
#
# Pour la population de 1996-2018, il s'agit d'estimations de population constituant une série historique de populations comparables ayant servi à la construction des projections de population basées sur le recensement de 2016.

# %%
pop_isq = pd.read_csv(path_data+'isq_pop_age_1996_2041.csv', sep=';')
pop_isq = pop_isq.set_index('year')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-212-6eb6a20b85b2> in <module>
# ----> 1 pop_isq = pd.read_csv(path_data+'isq_pop_age_1996_2041.csv', sep=';')
#       2 pop_isq = pop_isq.set_index('year')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/juliennavaux/Dropbox (CEDIA)/simgem/Benchmark/isq_pop_age_1996_2041.csv does not exist: '/Users/juliennavaux/Dropbox (CEDIA)/simgem/Benchmark/isq_pop_age_1996_2041.csv'

# %% [markdown]
# Population totale par âge sexe

# %%
pop_isq_age = pop_isq.drop(['total'],axis=1)
pop_isq_age_tot=pop_isq_age.loc[pop_isq['sex']=='all']
pop_isq_age_tot_m=pop_isq_age.loc[pop_isq['sex']=='male']
pop_isq_age_tot_f=pop_isq_age.loc[pop_isq['sex']=='female']
pop_isq_age_tot = pop_isq_age_tot.drop(['sex'],axis=1)
pop_isq_age_tot_m = pop_isq_age_tot_m.drop(['sex'],axis=1)
pop_isq_age_tot_f = pop_isq_age_tot_f.drop(['sex'],axis=1)

# %% [markdown]
# Population par groupe d'âge

# %%
pop_isq_age_tot_trans = pop_isq_age_tot.T
pop_isq_age_tot_trans
pop_isq_age_tot_trans['age']= range(0,91)
bins=list(range(0,96,5))
bins_3=[0,25,65,91]
pop_isq_age_tot_trans['agegr'] = pd.cut(pop_isq_age_tot_trans['age'], bins=bins, right=False)
gr=pop_isq_age_tot_trans.groupby(['agegr']).sum()
pop_isq_agegr_tot=gr.drop(['age'],axis=1).T
pop_isq_agegr_tot.columns= pop_isq_agegr_tot.columns.astype('str')
pop_isq_agegr_tot = pop_isq_agegr_tot[pop_isq_agegr_tot.index>=2017]
pop_isq_age_tot_trans['agegr'] = pd.cut(pop_isq_age_tot_trans['age'], bins=bins_3, right=False)
gr=pop_isq_age_tot_trans.groupby(['agegr']).sum()
pop_isq_agegr3_tot=gr.drop(['age'],axis=1).T
pop_isq_agegr3_tot.columns= pop_isq_agegr3_tot.columns.astype('str')
pop_isq_agegr3_tot = pop_isq_agegr3_tot[pop_isq_agegr3_tot.index>=2017]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-8e7fc23aff95> in <module>
# ----> 1 pop_isq_age_tot_trans = pop_isq_age_tot.T
#       2 pop_isq_age_tot_trans
#       3 pop_isq_age_tot_trans['age']= range(0,91)
#       4 bins=list(range(0,96,5))
#       5 bins_3=[0,25,65,91]
#
# NameError: name 'pop_isq_age_tot' is not defined

# %% [markdown]
# Population totale par sexe

# %%
pop_isq_total=pop_isq.loc[pop_isq['sex']=='all']
pop_isq_total =pop_isq_total['total']
pop_isq_total_m = pop_isq.loc[pop_isq['sex']=='male']
pop_isq_total_m =pop_isq_total_m['total']
pop_isq_total_f = pop_isq.loc[pop_isq['sex']=='female']
pop_isq_total_f =pop_isq_total_f['total']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-214-53a173c727ae> in <module>
# ----> 1 pop_isq_total=pop_isq.loc[pop_isq['sex']=='all']
#       2 pop_isq_total =pop_isq_total['total']
#       3 pop_isq_total_m = pop_isq.loc[pop_isq['sex']=='male']
#       4 pop_isq_total_m =pop_isq_total_m['total']
#       5 pop_isq_total_f = pop_isq.loc[pop_isq['sex']=='female']
#
# NameError: name 'pop_isq' is not defined

# %% [markdown]
# ## Figue comparaison population
#
# ### Population totale

# %%
plt.figure(figsize=(10,5))
plt.plot(pop_isq_total, label='isq')
plt.plot(pop, label='simgen', linestyle='dashed')
plt.legend()
plt.title('Comparaison population totale')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-fedc09f6d1ec> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(pop_isq_total, label='isq')
#       3 plt.plot(pop, label='simgen', linestyle='dashed')
#       4 plt.legend()
#       5 plt.title('Comparaison population totale')
#
# NameError: name 'pop_isq_total' is not defined

# %% [markdown]
# ### Comparaison popuation par sexe

# %%
plt.figure(figsize=(10,5))
plt.plot(pop_isq_total_m[pop_isq_total_m.index>=2017], label='isq')
plt.plot(pop_m, label='simgen', linestyle='dashed')
plt.legend()
plt.title('Comparaison population homme')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-216-59cd68ac5132> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(pop_isq_total_m[pop_isq_total_m.index>=2017], label='isq')
#       3 plt.plot(pop_m, label='simgen', linestyle='dashed')
#       4 plt.legend()
#       5 plt.title('Comparaison population homme')
#
# NameError: name 'pop_isq_total_m' is not defined

# %%
plt.figure(figsize=(10,5))
plt.plot(pop_isq_total_f[pop_isq_total_m.index>=2017], label='isq')
plt.plot(pop_f, label='simgen', linestyle='dashed')
plt.legend()
plt.title('Comparaison population femme')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-217-6777986f5b8c> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(pop_isq_total_f[pop_isq_total_m.index>=2017], label='isq')
#       3 plt.plot(pop_f, label='simgen', linestyle='dashed')
#       4 plt.legend()
#       5 plt.title('Comparaison population femme')
#
# NameError: name 'pop_isq_total_f' is not defined

# %% [markdown]
# ### Comparaison population par groupe d'âge

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr3_tot['[0, 25)'], label='isq 0-25', color='blue')
plt.plot(pop_isq_agegr3_tot['[25, 65)'], label='isq 25-65', color='green')
plt.plot(pop_isq_agegr3_tot['[65, 91)'], label='isq 65+', color='red')
plt.plot(pop_age_gr3['(-1, 24]'], label='simgen 0-25',color='blue', linestyle='dashed')
plt.plot(pop_age_gr3['(24, 64]'], label='simgen 25-65',color='green', linestyle='dashed')
plt.plot(pop_age_gr3['(64, 101]'], label='simgen 65+',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-9de20162391b> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(pop_isq_agegr3_tot['[0, 25)'], label='isq 0-25', color='blue')
#       3 plt.plot(pop_isq_agegr3_tot['[25, 65)'], label='isq 25-65', color='green')
#       4 plt.plot(pop_isq_agegr3_tot['[65, 91)'], label='isq 65+', color='red')
#       5 plt.plot(pop_age_gr3['(-1, 24]'], label='simgen 0-25',color='blue', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr3_tot' is not defined

# %% [markdown]
# ### Comparaison groupe d'âge de 5 ans

# %%
plt.figure(figsize=(10,5))
plt.plot(pop_isq_agegr_tot['[0, 5)'], label='isq 0-5', color='blue')
plt.plot(pop_age_gr['(-1, 4]'], label='simgen 0-5',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[5, 10)'], label='isq 5-10', color='green')
plt.plot(pop_age_gr['(4, 9]'], label='simgen 5-10',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[10, 15)'], label='isq 10-15', color='red')
plt.plot(pop_age_gr['(9, 14]'], label='simgen 10-15',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 0-15")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-219-46c4ac94494d> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(pop_isq_agegr_tot['[0, 5)'], label='isq 0-5', color='blue')
#       3 plt.plot(pop_age_gr['(-1, 4]'], label='simgen 0-5',color='blue', linestyle='dashed')
#       4 plt.plot(pop_isq_agegr_tot['[5, 10)'], label='isq 5-10', color='green')
#       5 plt.plot(pop_age_gr['(4, 9]'], label='simgen 5-10',color='green', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr_tot' is not defined

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr_tot['[15, 20)'], label='isq 15-20', color='blue')
plt.plot(pop_age_gr['(14, 19]'], label='simgen 15-20',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[20, 25)'], label='isq 20-25', color='green')
plt.plot(pop_age_gr['(19, 24]'], label='simgen 20-25',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[25, 30)'], label='isq 25-30', color='red')
plt.plot(pop_age_gr['(24, 29]'], label='simgen 25-30',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 15-30")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-220-576d9c33c85f> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(pop_isq_agegr_tot['[15, 20)'], label='isq 15-20', color='blue')
#       3 plt.plot(pop_age_gr['(14, 19]'], label='simgen 15-20',color='blue', linestyle='dashed')
#       4 plt.plot(pop_isq_agegr_tot['[20, 25)'], label='isq 20-25', color='green')
#       5 plt.plot(pop_age_gr['(19, 24]'], label='simgen 20-25',color='green', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr_tot' is not defined

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr_tot['[30, 35)'], label='isq 30-35', color='blue')
plt.plot(pop_age_gr['(29, 34]'], label='simgen 30-35',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[35, 40)'], label='isq 35-40', color='green')
plt.plot(pop_age_gr['(34, 39]'], label='simgen 35-40',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[40, 45)'], label='isq 40-45', color='red')
plt.plot(pop_age_gr['(39, 44]'], label='simgen 40-45',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 30-45")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-221-7cb96c70b7d3> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(pop_isq_agegr_tot['[30, 35)'], label='isq 30-35', color='blue')
#       3 plt.plot(pop_age_gr['(29, 34]'], label='simgen 30-35',color='blue', linestyle='dashed')
#       4 plt.plot(pop_isq_agegr_tot['[35, 40)'], label='isq 35-40', color='green')
#       5 plt.plot(pop_age_gr['(34, 39]'], label='simgen 35-40',color='green', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr_tot' is not defined

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr_tot['[45, 50)'], label='isq 45-50', color='blue')
plt.plot(pop_age_gr['(44, 49]'], label='simgen 45-50',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[50, 55)'], label='isq 50-55', color='green')
plt.plot(pop_age_gr['(49, 54]'], label='simgen 50-55',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[55, 60)'], label='isq 55-60', color='red')
plt.plot(pop_age_gr['(54, 59]'], label='simgen 55-60',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 45-60")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr_tot['[60, 65)'], label='isq 60-65', color='blue')
plt.plot(pop_age_gr['(59, 64]'], label='simgen 60-65',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[65, 70)'], label='isq 65-70', color='green')
plt.plot(pop_age_gr['(64, 69]'], label='simgen 65-70',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[70, 75)'], label='isq 70-75', color='red')
plt.plot(pop_age_gr['(69, 74]'], label='simgen 70-75',color='red', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 60-75")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-222-a9f13a22fbdc> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(pop_isq_agegr_tot['[60, 65)'], label='isq 60-65', color='blue')
#       3 plt.plot(pop_age_gr['(59, 64]'], label='simgen 60-65',color='blue', linestyle='dashed')
#       4 plt.plot(pop_isq_agegr_tot['[65, 70)'], label='isq 65-70', color='green')
#       5 plt.plot(pop_age_gr['(64, 69]'], label='simgen 65-70',color='green', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr_tot' is not defined

# %%
plt.figure(figsize=(20,10))
plt.plot(pop_isq_agegr_tot['[75, 80)'], label='isq 75-80', color='blue')
plt.plot(pop_age_gr['(74, 79]'], label='simgen 75-80',color='blue', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[80, 85)'], label='isq 80-85', color='green')
plt.plot(pop_age_gr['(79, 84]'], label='simgen 80-85',color='green', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[85, 90)'], label='isq 85-90', color='red')
plt.plot(pop_age_gr['(84, 89]'], label='simgen 70-75',color='red', linestyle='dashed')
plt.plot(pop_isq_agegr_tot['[90, 95)'], label='isq 90+', color='black')
plt.plot(pop_age_gr['(89, 101]'], label='simgen 90+',color='black', linestyle='dashed')
plt.legend()
plt.title("Comparaison groupe d'âge 75-90")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-223-2e1b6257d269> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(pop_isq_agegr_tot['[75, 80)'], label='isq 75-80', color='blue')
#       3 plt.plot(pop_age_gr['(74, 79]'], label='simgen 75-80',color='blue', linestyle='dashed')
#       4 plt.plot(pop_isq_agegr_tot['[80, 85)'], label='isq 80-85', color='green')
#       5 plt.plot(pop_age_gr['(79, 84]'], label='simgen 80-85',color='green', linestyle='dashed')
#
# NameError: name 'pop_isq_agegr_tot' is not defined

# %% [markdown]
# ### Comparaison des naissances

# %%
plt.figure(figsize=(10,5))
plt.plot(pop_isq_age_tot.loc[2017:,'0'], label='isq', color='blue')
plt.plot(pop_age[0], label='simgen',color='blue', linestyle='dashed')
plt.legend()
plt.title("Naissances")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-f08b90aef4cd> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(pop_isq_age_tot.loc[2017:,'0'], label='isq', color='blue')
#       3 plt.plot(pop_age[0], label='simgen',color='blue', linestyle='dashed')
#       4 plt.legend()
#       5 plt.title("Naissances")
#
# NameError: name 'pop_isq_age_tot' is not defined

# %% [markdown]
# # Éducation
#
# ## Extraction des données SimGen
#
# Prenant en compte school_done

# %%
popeduc = base.stats.freq('educ')
propeduc15over = base.stats.prop('educ',sub='age>=15')
propeduc25overinsch = base.stats.prop('educ',sub='age>=25 and insch==False')
propeduc35overinsch = base.stats.prop('educ',sub='age>=35 and insch==False')
propeduc3544 = base.stats.prop('educ',sub='age>=35 and age<=44')
propeduc2564 = base.stats.prop('educ',sub='age>=25 and age<=64')
propeduc15overinsch = base.stats.prop('educ',sub='age>=15 and insch==False')
propeduc3544insch = base.stats.prop('educ',sub='age>=35 and age<=44 and insch==False')
propeduc2564insch = base.stats.prop('educ',sub='age>=25 and age<=64 and insch==False')

# %% [markdown]
# ## Chargement des données isq
#
# Source : Statistique Canada (SC), Enquête sur la population active (EPA), compilations de Statistique Canada et de l'Institut de la statistique du Québec réalisées grâce à l'accès aux données du Centre interuniversitaire québécois de statistiques sociales (CIQSS), membre du Réseau canadien des Centres de données de recherche (RCCDR). Adapté par l’Institut de la statistique du Québec (ISQ).
#
# Mise à jour : 28 novembre 2019
#
# https://www.stat.gouv.qc.ca/statistiques/education/niveau-scolarite/repartition-scol-ra-sexe-age.html#tri_tertr=50040000000000000&tri_sexe=1&tri_age=365&tri_stat=8403

# %%
pop_educ = pd.read_csv(path_data+'educ4_qc2.csv', sep=';')
pop_educ = pop_educ[pop_educ['year']>=2000]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-226-8136af97c623> in <module>
# ----> 1 pop_educ = pd.read_csv(path_data+'educ4_qc2.csv', sep=';')
#       2 pop_educ = pop_educ[pop_educ['year']>=2000]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/juliennavaux/Dropbox (CEDIA)/simgem/Benchmark/educ4_qc2.csv does not exist: '/Users/juliennavaux/Dropbox (CEDIA)/simgem/Benchmark/educ4_qc2.csv'

# %% [markdown]
# Préparation des données par groupe d'âge

# %%
prop_educ_15over = pop_educ[pop_educ['age']=='15 ans et plus'] 
prop_educ_15over = prop_educ_15over[prop_educ_15over['sex']=='Total (hommes-femmes)']
prop_educ_15over = prop_educ_15over.set_index('year')
prop_educ_15over = prop_educ_15over.drop(columns=['age','sex','pop'])
prop_educ_3544 = pop_educ[pop_educ['age']=='35-44 ans'] 
prop_educ_3544 = prop_educ_3544[prop_educ_3544['sex']=='Total (hommes-femmes)']
prop_educ_3544 = prop_educ_3544.set_index('year')
prop_educ_3544 = prop_educ_3544.drop(columns=['age','sex','pop'])
prop_educ_2564 = pop_educ[pop_educ['age']=='25-64 ans'] 
prop_educ_2564 = prop_educ_2564[prop_educ_2564['sex']=='Total (hommes-femmes)']
prop_educ_2564 = prop_educ_2564.set_index('year')
prop_educ_2564 = prop_educ_2564.drop(columns=['age','sex','pop'])

# %% [markdown]
# Data Census

# %%
census_educ = pd.read_csv(path_data+'census_educ.csv', sep=";")
census_educ.head()

# %%
prop_educ_15over = census_educ[census_educ['age']=='15 ans et plus'] 
prop_educ_15over = prop_educ_15over[prop_educ_15over['sex']=='Total (hommes-femmes)']
prop_educ_15over = prop_educ_15over.set_index('year')
prop_educ_15over = prop_educ_15over.drop(columns=['age','sex','pop'])
prop_educ_3544 = census_educ[census_educ['age']=='35-44 ans'] 
prop_educ_3544 = prop_educ_3544[prop_educ_3544['sex']=='Total (hommes-femmes)']
prop_educ_3544 = prop_educ_3544.set_index('year')
prop_educ_3544 = prop_educ_3544.drop(columns=['age','sex','pop'])
prop_educ_2564 = census_educ[census_educ['age']=='25-64 ans'] 
prop_educ_2564 = prop_educ_2564[prop_educ_2564['sex']=='Total (hommes-femmes)']
prop_educ_2564 = prop_educ_2564.set_index('year')
prop_educ_2564 = prop_educ_2564.drop(columns=['age','sex','pop'])

# %% [markdown]
# Petite fonction pour graphiques d'éducation

# %%
def graph_educ(isq,simgen,title, save=False, save_path=None, save_name=None):
    plt.figure(figsize=(10,5))
    plt.plot(isq['prop'][isq['educ4']=='uni'],label='census uni', color='blue')
    plt.plot(simgen['uni'], label='simgen uni',color='blue', linestyle='dashed')
    plt.plot(isq['prop'][isq['educ4']=='dec'],label='census dec', color='green')
    plt.plot(simgen['dec'], label='simgen dec',color='green', linestyle='dashed')
    plt.plot(isq['prop'][isq['educ4']=='des'],label='census des', color='red')
    plt.plot(simgen['des'], label='simgen des',color='red', linestyle='dashed')
    plt.plot(isq['prop'][isq['educ4']=='none'],label='census none', color='black')
    plt.plot(simgen['none'], label='simgen des',color='black', linestyle='dashed')
    plt.legend()
    plt.title(title)
    if save:
        #plt.savefig(save_path + save_name + '.jpg')
        plt.savefig(save_path + save_name + '.png')
    plt.show()

# %% [markdown]
# ### Graphiques comparaison éducation

# %%
graph_educ(isq=prop_educ_15over,simgen=propeduc15overinsch,title='Éducation 15 ans et plus')

# %%
graph_educ(isq=prop_educ_3544, simgen=propeduc3544insch, title='Éducation 35-44 ans')

# %%
graph_educ(isq=prop_educ_2564,simgen=propeduc2564,
           title="Figure3: Proportion de la population par niveau de scolarité, 25-64 ans, Québec, 2006-2040",
          save=True, save_path="/Users/ydecarie/Dropbox (CEDIA)/OLG_CAN/demo/simgen-docs/figure/",
          #save=True, save_path="/Users/juliennavaux/Dropbox (CEDIA)/OLG_CAN/demo/simgen-docs/figure/",
          save_name="educ_2564")

# %%
graph_educ(isq=prop_educ_2564,simgen=propeduc2564insch,title='Éducation 25-64 ans')

# %% [raw]
#       Tableau BDSPS 25-65 ans
#
#       études |      Freq.           Percent        Cum.
# ------------+-----------------------------------
#           dec | 11,957.777       37.21       37.21
#           des | 7,941.3249       24.71       61.92
#        none | 5,554.9971       17.29       79.21
#           uni | 6,681.9009       20.79      100.00
# Les premières années du modèle ne collent pas avec la base qui est similaire à l'ISQ

# %% [markdown]
# ## Comparaison des personnes en couple

# %% [markdown]
# ### Extraction données SimGen
#
# Proportion des personnes en couple par groupe d'âge

# %%
popms = base.stats.freq('married')
propms15plus = base.stats.prop('married', sub="age>=15")
propms1544 = base.stats.prop('married', sub="age>=15 and age<=44")
propms4564 = base.stats.prop('married', sub="age>=45 and age<=64")
propms65plus = base.stats.prop('married', sub="age>=65")
propms15plus.columns= propms15plus.columns.astype('str')
propms1544.columns= propms1544.columns.astype('str')
propms4564.columns= propms4564.columns.astype('str')
propms65plus.columns= propms65plus.columns.astype('str')

# %% [markdown]
# ### Extraction données Statistique Canada
#
# Estimations de la population au 1er juillet, selon l'état matrimonial ou l'état matrimonial légal, l'âge et le sexe, Tableau : 17-10-0060-01
#
# https://www150.statcan.gc.ca/t1/tbl1/fr/cv.action?pid=1710006001

# %%
pop_ms = pd.read_csv(path_data+'married_qc.csv', sep=';')
pop_ms=pop_ms[pop_ms['married']==1]
pop_ms_15plus = pop_ms[pop_ms["age"]=="15 ans et plus"]
pop_ms_15plus = pop_ms_15plus.set_index(pop_ms_15plus["year"])
pop_ms_1544 = pop_ms[pop_ms["age"]=="15 à 44 ans"]
pop_ms_1544 = pop_ms_1544.set_index(pop_ms_1544["year"])
pop_ms_4564 = pop_ms[pop_ms["age"]=="45 à 64 ans"]
pop_ms_4564 = pop_ms_4564.set_index(pop_ms_4564["year"])
pop_ms_65plus = pop_ms[pop_ms["age"]=="65 ans et plus"]
pop_ms_65plus = pop_ms_65plus.set_index(pop_ms_65plus["year"])

# %% [markdown]
# Petite fonction pour graphiques de comparaison des unions

# %%
def graph_union(isq,simgen,title, save=False, save_path=None, save_name=None):
    plt.figure(figsize=(10,5))
    plt.plot(isq['prop'], label='isq couple',color='blue')
    plt.plot(1-isq['prop'],label="isq single",color='green')
    plt.plot(simgen["True"],label="simgen couple", color="blue", linestyle='dashed')
    plt.plot(1-simgen["True"], label='simgen single',color='green', linestyle='dashed')
    plt.legend()
    plt.title(title)
    if save:
        #plt.savefig(save_path + save_name + '.jpg')
        plt.savefig(save_path + save_name + '.png')

# %% [markdown]
# ### Graphiques comparaioson des personnes en couple par groupe d'âge

# %%
graph_union(pop_ms_15plus,propms15plus,title=" Figure 4: Proportion des personnes de 15 ans et plus en couple, Québec, 2000-2040", save=True,
            save_path="/Users/ydecarie/Dropbox (CEDIA)/OLG_CAN/demo/simgen-docs/figure/", 
            #save_path="/Users/juliennavaux/Dropbox (CEDIA)/OLG_CAN/demo/simgen-docs/figure/",
            save_name="union_15over")

# %%
graph_union(pop_ms_1544,propms1544,title="Union 15-44 ans")

# %%
graph_union(pop_ms_4564,propms4564,title="Union 45-64 ans")

# %%
graph_union(pop_ms_65plus,propms65plus,title="Union 65 plus")

# %% [markdown]
# Comparaison education données de Statistiques Canada

# %%
pop_educ_stc = pd.read_csv(path_data+'educ4_qc_stc.csv', sep=';')
pop_educ_stc = pop_educ_stc[pop_educ_stc['year']>=2000]
pop_educ_stc

# %%
prop_educ_stc_15over = pop_educ_stc[pop_educ_stc['age']=='15 ans et plus'] 
prop_educ_stc_15over = prop_educ_stc_15over[prop_educ_stc_15over['sex']=='Total (hommes-femmes)']
prop_educ_stc_15over = prop_educ_stc_15over.set_index('year')
prop_educ_stc_15over = prop_educ_stc_15over.drop(columns=['age','sex','pop'])
prop_educ_stc_25over = pop_educ_stc[pop_educ_stc['age']=='25 ans et plus'] 
prop_educ_stc_25over = prop_educ_stc_25over[prop_educ_stc_25over['sex']=='Total (hommes-femmes)']
prop_educ_stc_25over = prop_educ_stc_25over.set_index('year')
prop_educ_stc_25over = prop_educ_stc_25over.drop(columns=['age','sex','pop'])

prop_educ_stc_35over = pop_educ_stc[pop_educ_stc['age']=='25 ans et plus'] 
prop_educ_stc_35over = prop_educ_stc_35over[prop_educ_stc_35over['sex']=='Total (hommes-femmes)']
prop_educ_stc_35over = prop_educ_stc_35over.set_index('year')
prop_educ_stc_35over = prop_educ_stc_35over.drop(columns=['age','sex','pop'])

prop_educ_stc_3544 = pop_educ_stc[pop_educ_stc['age']=='35-44 ans'] 
prop_educ_stc_3544 = prop_educ_stc_3544[prop_educ_stc_3544['sex']=='Total (hommes-femmes)']
prop_educ_stc_3544 = prop_educ_stc_3544.set_index('year')
prop_educ_stc_3544 = prop_educ_stc_3544.drop(columns=['age','sex','pop'])
prop_educ_stc_2564 = pop_educ_stc[pop_educ_stc['age']=='25-64 ans'] 
prop_educ_stc_2564 = prop_educ_stc_2564[prop_educ_stc_2564['sex']=='Total (hommes-femmes)']
prop_educ_stc_2564 = prop_educ_stc_2564.set_index('year')
prop_educ_stc_2564 = prop_educ_stc_2564.drop(columns=['age','sex','pop'])

# %%
graph_educ(isq=prop_educ_stc_25over,simgen=propeduc25overinsch,title='Éducation 25 ans et plus')

# %%
prop_educ_stc_35over

# %%
prop_educ_15over

# %%
graph_educ(isq=prop_educ_stc_35over, simgen=propeduc35overinsch, title="")

# %% [markdown]
# ## Graphique Étudiants

# %%
base.stats.freq("age", sub='insch==True and age>=17 and age<=35').T.sum().plot()

# %%
base.stats.freq("age", sub='age>=16 and age <25').plot()

# %% [markdown]
# ## Famille

# %%
base.stats.freq("nkids", sub="nkids>0").T.sum().plot()

# %%
kids_count = [0,1,2,8]
base.stats.freq("nkids", bins=kids_count).plot()

# %%
nkids_couple=base.stats.freq("nkids", bins=kids_count, sub="married==True")
nkids_couple=nkids_couple/2
nkids_couple.plot()

# %%
nkids_single=base.stats.freq("nkids", bins=kids_count, sub="married==False")
nkids_single.plot()

# %%
nkids= nkids_couple+nkids_single
nkids.plot()

# %%
bk = [0, 8]
kids_couple=base.stats.freq("nkids", bins=bk, sub="married==True")
kids_couple=kids_couple/2
kids_single=base.stats.freq("nkids", bins=bk, sub="married==False")
kids = kids_single+kids_couple
kids.plot()

# %%
base.stats.freq('age', sub="age==18").plot()

# %%
base.stats.freq("age", sub="insch==True and age>34").T.sum().plot()

# %%
base.stats.freq("age", sub="insch==True and age>=35 and age<=65").T.sum().plot()

# %%
base.stats.freq("age", sub="insch==True and age>=35 and age<=45").plot()
